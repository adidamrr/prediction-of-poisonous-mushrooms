# %% [markdown]
# ## 1. EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, FunctionTransformer
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("../data/train.csv", index_col = "id")

# %%
df
# Out:
#         class  cap-diameter cap-shape cap-surface cap-color  \
# id
# 0           e          8.80         f           s         u
# 1           p          4.51         x           h         o
# 2           e          6.94         f           s         b
# 3           e          3.88         f           y         g
# 4           e          5.85         x           l         w
# ...       ...           ...       ...         ...       ...
# 3116940     e          9.29         f         NaN         n
# 3116941     e         10.88         s         NaN         w
# 3116942     p          7.82         x           e         e
# 3116943     e          9.45         p           i         n
# 3116944     p          3.20         x           s         g
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  \
# id
# 0                          f               a            c          w
# 1                          f               a            c          n
# ...

# %%
df.isna().sum()
# Out:
# class                         0
# cap-diameter                  4
# cap-shape                    40
# cap-surface              671023
# cap-color                    12
# does-bruise-or-bleed          8
# gill-attachment          523936
# gill-spacing            1258435
# gill-color                   57
# stem-height                   0
# stem-width                    0
# stem-root               2757023
# stem-surface            1980861
# stem-color                   38
# veil-type               2957493
# veil-color              2740947
# has-ring                     24
# ring-type                128880
# spore-print-color       2849682
# habitat                      45
# season                        0
# dtype: int64

# %%
df = df.drop(columns=["cap-surface", "gill-attachment", "gill-spacing", "stem-root", "stem-surface", "veil-type", "veil-color", "spore-print-color"])

# %%
df
# Out:
#         class  cap-diameter cap-shape cap-color does-bruise-or-bleed  \
# id
# 0           e          8.80         f         u                    f
# 1           p          4.51         x         o                    f
# 2           e          6.94         f         b                    f
# 3           e          3.88         f         g                    f
# 4           e          5.85         x         w                    f
# ...       ...           ...       ...       ...                  ...
# 3116940     e          9.29         f         n                    t
# 3116941     e         10.88         s         w                    t
# 3116942     p          7.82         x         e                    f
# 3116943     e          9.45         p         n                    t
# 3116944     p          3.20         x         g                    f
#
#         gill-color  stem-height  stem-width stem-color has-ring ring-type  \
# id
# ...

# %%
X = df.drop(columns=["class"])
y = df["class"]

# %%
sns.histplot(y)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)

# %%
num_features = ["cap-diameter", "stem-height", "stem-width", ]
cat_features = ["cap-shape", "cap-color", "does-bruise-or-bleed", "gill-color", "stem-color", "ring-type", "habitat", "season"]
binary_cat_features = ["has-ring"]

# %%
sns.histplot(X_train["cap-diameter"])
# Out:
# <Axes: xlabel='cap-diameter', ylabel='Count'>

# %%
y_train[X_train["cap-diameter"] > 57].value_counts()
# Out:
# class
# e    164
# p      4
# Name: count, dtype: int64

# %%
def drop_objects(X_input, y_input, col_name, max_t=None, min_t=None):
    X = X_input.copy()
    y = y_input.copy()
    if max_t:
        y = y.drop(y[X[col_name] > max_t].index)
        X = X.drop(X[X[col_name] > max_t].index)

    if min_t:
        y = y.drop(y[X[col_name] < min_t].index)
        X = X.drop(X[X[col_name] < min_t].index)

    return X, y

# %%
X_train, y_train = drop_objects(X_train, y_train, "cap-diameter", max_t=57)

# %%
sns.histplot(np.log1p(X_train["cap-diameter"]))
# Out:
# <Axes: xlabel='cap-diameter', ylabel='Count'>

# %%
X_train["cap-shape"].value_counts()
# Out:
# cap-shape
# x        1077116
# f         507242
# s         273842
# b         238799
# o          81400
# p          80159
# c          78554
# d             52
# e             42
# n             34
# g             29
# t             27
# w             26
# y             26
# r             25
# a             22
# u             20
# l             16
# z             15
# i             12
# k             10
# h              4
# 7 x            2
# 4.97           2
# 20.25          1
# 5.15           1
# b f            1
# 10.13          1
# 0.82           1
# 7.21           1
# is s           1
# 49.21          1
# 7.41           1
# 19.06          1
# 4.3            1
# 3.91           1
# 2.63           1
# 8              1
# 3.6            1
# 21.56          1
# m              1
# 17.44          1
# 6.21           1
# is p           1
# 54.78          1
# 2.82           1
# 24.16          1
# 8.3            1
# 3.37           1
# 7.43           1
# 3.55           1
# 19.04          1
# ...

# %%
X["cap-color"].value_counts()
# Out:
# cap-color
# n        1359542
# y         386627
# w         379442
# g         210825
# e         197290
#           ...
# 20.02          1
# 20             1
# 25.98          1
# 8.67           1
# 9.02           1
# Name: count, Length: 78, dtype: int64

# %%
sns.histplot(X_train["stem-height"])
# Out:
# <Axes: xlabel='stem-height', ylabel='Count'>

# %%
y_train[X_train["stem-height"] > 30].value_counts()
# Out:
# class
# e    154
# p      6
# Name: count, dtype: int64

# %%
X_train, y_train = drop_objects(X_train, y_train, "stem-height", max_t=57)

# %%
sns.histplot(np.log1p(X_train["stem-height"]))
# Out:
# <Axes: xlabel='stem-height', ylabel='Count'>

# %%
np.sort(X_train["stem-width"].unique())
# Out:
# array([  0.  ,   0.44,   0.48, ..., 101.69, 102.48, 102.9 ], shape=(5665,))

# %%
sns.histplot(X_train["stem-width"])
plt.show()

# %%
y_train[X_train["stem-width"] > 60].value_counts()
# Out:
# class
# e    705
# p     31
# Name: count, dtype: int64

# %%
X_train, y_train = drop_objects(X_train, y_train, "stem-width", max_t=60)

# %%
sns.histplot(np.log1p(X_train["stem-width"]))
plt.show()

# %%
X_train["has-ring"].value_counts()
# Out:
# has-ring
# f             1775631
# t              561060
# h                  11
# r                  10
# c                  10
# s                  10
# l                   8
# p                   7
# g                   6
# z                   5
# e                   4
# x                   4
# m                   3
# d                   3
# y                   3
# k                   2
# o                   2
# n                   2
# a                   1
# f has-ring          1
# w                   1
# Name: count, dtype: int64

# %%
X_train["season"].value_counts()
# Out:
# season
# a    1157829
# u     864521
# w     208189
# s     106263
# Name: count, dtype: int64

# %%
# все сатегориальные признаки в кастомный класс
# все числовые под логарифм
# распределение клакссов норм
# бинарный отдельно
# изменил все числовые колонки (удалил объекты с шумом) и бинарный категориальный

# %% [markdown]
# ## 2. Обучение логистической регрессии (baseline)

# %%
class RareCategory(BaseEstimator, TransformerMixin):
    def __init__(self, columns: list, min_freq: int, col_name="other"):
        self.col_name = col_name
        self.columns = columns
        self.min_freq = min_freq

    def fit(self, X, y=None):
        self.rare_categories_ = {}
        X_copy = X.copy().astype(str)
        for col in self.columns:
            freq = X_copy[col].value_counts(dropna=False)
            self.rare_categories_[col] = set(freq[freq < self.min_freq].index)
        return self

    def transform(self, X):
        X_copy = X.copy().astype(str)
        for col in self.columns:
            indexes = X_copy[col].isin(self.rare_categories_[col])
            X_copy.loc[indexes, col] = self.col_name
        return X_copy

# %%
class BinaryCategoricalFeature(BaseEstimator, TransformerMixin):
    def __init__(self, columns):
        self.columns = columns

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X_copy = X.copy()
        replaces = {"t": 1, "f": 0}
        for col_name in self.columns:
            X_copy[col_name] = X_copy[col_name].map(replaces)
        return X_copy

# %%
num_pipe = Pipeline([
    ("imputer", SimpleImputer(strategy="mean")),
    ('log', FunctionTransformer(np.log1p, validate=False)),
    ('scaler', StandardScaler())
])

cat_pipe = Pipeline([
    ("rare", RareCategory(columns=cat_features, min_freq=200)),
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ('ohe', OneHotEncoder(handle_unknown="ignore"))
])

bin_cat_pipe = Pipeline([
    ('tonum', BinaryCategoricalFeature(columns=binary_cat_features)),
    ("imputer", SimpleImputer(strategy="most_frequent"))
])

# %%
transformer = ColumnTransformer([
    ('num', num_pipe, num_features),
    ('cat', cat_pipe, cat_features),
    ('bin', bin_cat_pipe, binary_cat_features)
], remainder="drop")

# %%
logreg = LogisticRegression(C=0.5, solver="saga", max_iter=1000)

# %%
model = Pipeline([
    ('transformer', transformer),
    ('model', logreg)
])

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('log',
#                                                                    FunctionTransformer(func=<ufunc 'log1p'>)),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['cap-diameter',
#                                                    'stem-height',
#                                                    'stem-width']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('rare',
# ...

# %%
pred = model.predict_proba(X_test)[:, 1]

# %%
preds = model.predict(X_test)

# %%
from sklearn.metrics import roc_auc_score

# %%
roc_auc_score(y_test, pred)
# Out:
# 0.8094316288656492

# %% [markdown]
# ## 3. CatBoost

# %%
X_train, X_test, y_train, y_test = train_test_split(X[cat_features + num_features + binary_cat_features], y, test_size=0.25, random_state=42, stratify=y)

# %%
import pandas as pd
from catboost import Pool, CatBoostClassifier

# %%
y_tr = (y_train.astype(str) == "p").astype(int)
y_va = (y_test.astype(str) == "p").astype(int)

cat_cols = cat_features+binary_cat_features

cat_idx = [X_train.columns.get_loc(c) for c in cat_cols]

nan_token = "__nan__"
X_tr = X_train.copy()
X_va = X_test.copy()
X_tr[num_features] = np.log1p(X_tr[num_features])
X_va[num_features] = np.log1p(X_va[num_features])
X_tr[cat_cols] = X_tr[cat_cols].fillna(nan_token).astype(str)
X_va[cat_cols] = X_va[cat_cols].fillna(nan_token).astype(str)

train_pool = Pool(X_tr, y_tr, cat_features=cat_idx)
val_pool   = Pool(X_va, y_va, cat_features=cat_idx)

model = CatBoostClassifier(
    loss_function="Logloss",
    eval_metric="AUC",
    iterations=200,
    learning_rate=0.08,
    depth=10,
    l2_leaf_reg=8,
    random_strength=1.5,
    od_type="Iter",
    od_wait=200,
    verbose=20,
    allow_writing_files=False,
    bootstrap_type="Bernoulli",
    subsample=0.8,
)


model.fit(train_pool, eval_set=val_pool, use_best_model=True)

p_va = model.predict_proba(val_pool)[:, 1]
print("VAL AUC:", roc_auc_score(y_va, p_va))
# Out:
# 0:	test: 0.8627364	best: 0.8627364 (0)	total: 1.29s	remaining: 4m 16s
# 20:	test: 0.9872893	best: 0.9872893 (20)	total: 24.1s	remaining: 3m 25s
# 40:	test: 0.9918686	best: 0.9918686 (40)	total: 49.8s	remaining: 3m 13s
# 60:	test: 0.9935325	best: 0.9935325 (60)	total: 1m 16s	remaining: 2m 53s
# 80:	test: 0.9942258	best: 0.9942258 (80)	total: 1m 43s	remaining: 2m 31s
# 100:	test: 0.9946188	best: 0.9946188 (100)	total: 2m 9s	remaining: 2m 7s
# 120:	test: 0.9948829	best: 0.9948829 (120)	total: 2m 37s	remaining: 1m 42s
# 140:	test: 0.9950412	best: 0.9950412 (140)	total: 3m 4s	remaining: 1m 17s
# 160:	test: 0.9951636	best: 0.9951636 (160)	total: 3m 35s	remaining: 52.1s
# 180:	test: 0.9952569	best: 0.9952569 (180)	total: 4m 8s	remaining: 26.1s
# 199:	test: 0.9953296	best: 0.9953296 (199)	total: 4m 39s	remaining: 0us
#
# bestTest = 0.9953296047
# bestIteration = 199
#
# VAL AUC: 0.9953296047043615

# %% [markdown]
# ## 4. Подбор лучшего порога по recall

# %%
from sklearn.metrics import recall_score, precision_score

# %%
def find_best_t(y_va, p_va, target=0.5, cnt_of_variance=20) -> float:
    t_list = np.linspace(0, 1, cnt_of_variance)
    res_list = []
    for t in t_list:
        pred_va = (p_va >= t).astype(int)
        val_recall = recall_score(y_va, pred_va, zero_division = 0)
        val_precision = precision_score(y_va, pred_va, zero_division = 0)
        res_list.append(
            {"t" : t,
             "val_recall" : val_recall,
             "val_precision": val_precision
            })
    
    best_res_list = [res for res in res_list if res["val_recall"] >= target]
    if best_res_list:
        best_res = sorted(best_res_list, key=lambda x:(x["val_precision"], x["val_recall"]))[-1]
        best_t = best_res["t"]
        print(f"best t = {best_t} with recall = {best_res['val_recall']} and precision = {best_res['val_precision']}")
        return best_t
    print("Нет такого значения recall")
    return 0.5

# %%
best_t = find_best_t(y_va, p_va, target=0.991, cnt_of_variance=40)
# Out:
# best t = 0.1282051282051282 with recall = 0.9916852156332019 and precision = 0.9517832259923507

# %% [markdown]
# ## 5. Submission на тестовых данных для Kaggle

# %%
X, y = drop_objects(X, y, "cap-diameter", max_t=57)
X, y = drop_objects(X, y, "stem-height", max_t=57)
X, y = drop_objects(X, y, "stem-width", max_t=60)

# %%
X_train, X_test, y_train, y_test = train_test_split(X[cat_features + num_features + binary_cat_features], y, test_size=0.25, random_state=42, stratify=y)

# %%
X_test = pd.read_csv("../data/test.csv")
X_t = X_test.copy()
X_t[cat_cols] = X_t[cat_cols].fillna(nan_token).astype(str)
X_t[num_features] = np.log1p(X_t[num_features])

# %%
np.concat([X_tr,X_va])
# Out:
# array([['s', 'o', 'f', ..., 1.9851308622085946, 2.6210388241125804, 'f'],
#        ['f', 'y', 'f', ..., 2.033397603178429, 2.432735777459091, 'f'],
#        ['x', 'o', 'f', ..., 1.925707441737794, 1.9851308622085946, 'f'],
#        ...,
#        ['x', 'w', 't', ..., 2.1377104498038118, 2.6232182655855123, 't'],
#        ['b', 'k', 'f', ..., 2.4042387467205457, 1.3376291891386096, 'f'],
#        ['s', 'w', 't', ..., 1.9065751436566365, 2.925309809257445, 'f']],
#       shape=(3116945, 12), dtype=object)

# %%
y_tr = (y_train.astype(str) == "p").astype(int)
y_va = (y_test.astype(str) == "p").astype(int)

cat_cols = cat_features+binary_cat_features

cat_idx = [X_train.columns.get_loc(c) for c in cat_cols]

nan_token = "__nan__"
X_tr = X_train.copy()
X_va = X_test.copy()
X_tr[num_features] = np.log1p(X_tr[num_features])
X_va[num_features] = np.log1p(X_va[num_features])
X_tr[cat_cols] = X_tr[cat_cols].fillna(nan_token).astype(str)
X_va[cat_cols] = X_va[cat_cols].fillna(nan_token).astype(str)

train_pool = Pool(X_tr, y_tr, cat_features=cat_idx)
val_pool   = Pool(X_va, y_va, cat_features=cat_idx)
full_pool = Pool(np.concat([X_tr,X_va]), np.concat([y_tr,y_va]), cat_features=cat_idx)

model = CatBoostClassifier(
    loss_function="Logloss",
    eval_metric="AUC",
    iterations=1000,
    learning_rate=0.05,
    depth=10,
    l2_leaf_reg=8,
    random_strength=1.5,
    od_type="Iter",
    od_wait=200,
    verbose=20,
    allow_writing_files=False,
    bootstrap_type="Bernoulli",
    subsample=0.8,
)

model.fit(full_pool)
# Out:
# 0:	total: 1.53s	remaining: 5m 5s
# 20:	total: 30.5s	remaining: 4m 19s
# 40:	total: 1m 1s	remaining: 3m 59s
# 60:	total: 1m 32s	remaining: 3m 31s
# 80:	total: 2m 6s	remaining: 3m 5s
# 100:	total: 2m 41s	remaining: 2m 38s
# 120:	total: 3m 15s	remaining: 2m 7s
# 140:	total: 4m 2s	remaining: 1m 41s
# 160:	total: 4m 47s	remaining: 1m 9s
# 180:	total: 5m 33s	remaining: 35s
# 199:	total: 6m 21s	remaining: 0us
# CatBoostClassifier(allow_writing_files=False, bootstrap_type='Bernoulli', depth=10, eval_metric='AUC', iterations=200, l2_leaf_reg=8, learning_rate=0.08, loss_function='Logloss', od_type='Iter', od_wait=200, random_strength=1.5, subsample=0.8, verbose=20)

# %%
pred = model.predict(X_t[cat_features + num_features + binary_cat_features])
pred = np.where(pred==1, "p", "e")

# %%
answers = pd.read_csv("../data/sample_submission.csv", index_col = "id")
answers["class"] = pred
answers
# Out:
#         class
# id
# 3116945     e
# 3116946     p
# 3116947     p
# 3116948     p
# 3116949     e
# ...       ...
# 5194904     p
# 5194905     p
# 5194906     p
# 5194907     e
# 5194908     e
#
# [2077964 rows x 1 columns]

# %%
answers.to_csv("../data/submission.csv")

# %% [markdown]
# ## 6. Экспорт модели

# %%
import json

model.save_model("../model/model.cbm")

meta = {
    "threshold": best_t,
    "num_cols": num_features,
    "cat_cols": cat_cols,
    "nan_token": "__nan__",
    "positive_label": "p",
    "negative_label": "e",
}

with open("../model/meta.json", "w", encoding="utf-8") as f:
    json.dump(meta, f, ensure_ascii=False, indent=2)

# %% [markdown]
# ## 7. Результат
# В результате получилось **Score: 0.96158**
#
# ![image.png](attachment:0143c35b-f2b6-4728-b036-5a5a4df0b82f.png)
